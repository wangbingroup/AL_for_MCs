# %%
# %run eval.ipynb
import pickle
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utils import eval, visual, save, save_model
from model import Model
import warnings
warnings.filterwarnings('ignore')

from ngboost import NGBRegressor
from ngboost.distns import Normal
from ngboost.scores import CRPS
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import cross_validate, KFold

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data = pd.read_excel('data/1_air.xlsx', sheet_name='Sheet1', index_col=0)
data.columns = data.columns.str.strip()  

feature_names = ["CurrentDensity", "O2", "CO2"]
X = data[feature_names].to_numpy()
y = data["overpotential"].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

print("train:", X_train_scaled.shape)  # -> (n, 3)
print("test:", X_test_scaled.shape)
# Out:
# train: (106, 3)
# test: (27, 3)

# %%
with open('model/scaler_2_air.pkl', 'wb') as f:
    pickle.dump(scaler_X, f)

# %% [markdown]
# # NGBoost

# %%
ngb = NGBRegressor(
    Dist=Normal,      
    Score=CRPS,       
    n_estimators=200,
    learning_rate=0.2,
    verbose=False
)


model = Model(ngb, X_train, X_test, y_train, y_test, 'nGBoost', 'air_1')

visual(model, 'ngboost', X_train, X_test, y_train, y_test)

kf = KFold(n_splits=5, shuffle=True, random_state=43)

scoring = {
    'r2': make_scorer(r2_score),
    'mae': make_scorer(mean_absolute_error),
    'rmse': make_scorer(lambda y_true, y_pred: np.sqrt(mean_squared_error(y_true, y_pred)))
}

cv_results = cross_validate(
    ngb, X_train, y_train,
    cv=kf,
    scoring=scoring,
    return_train_score=False
)

r2_mean,  r2_std  = cv_results['test_r2'].mean(),  cv_results['test_r2'].std(ddof=1)
mae_mean, mae_std = cv_results['test_mae'].mean(), cv_results['test_mae'].std(ddof=1)
rmse_mean,rmse_std= cv_results['test_rmse'].mean(),cv_results['test_rmse'].std(ddof=1)

print(f"\n【CV-{kf.get_n_splits()}】  "
      f"R²={r2_mean:.6f}±{r2_std:.6f} | "
      f"MAE={mae_mean:.6f}±{mae_std:.6f} | "
      f"RMSE={rmse_mean:.6f}±{rmse_std:.6f}")
# Out:
# nGBoost train:
#  r2: 0.7879216416745134  rmse: 0.08624178620580719  mse:0.007437645687968156 error_ratio:1.78% mae:0.029573799425286585
# nGBoost test:
#  r2: 0.7430418305496407  rmse: 0.09968422501319867 mse:0.009936944716482023 error_ratio:5.29% mae:0.07739212181460849
# save result successful！
# 【CV-5】  R²=0.460787±0.246680 | MAE=0.082739±0.011317 | RMSE=0.118612±0.046830

# %%
save_model(ngb, 'NGBoost_1_air')
# Out:
# save NGBoost_1_air model successful
